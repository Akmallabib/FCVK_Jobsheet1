# %% [markdown]
# <a href="https://colab.research.google.com/github/Akmallabib/FCVK_Jobsheet1/blob/main/PCVK_Jobsheet1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MODUL 1 - Membaca dan Menampilkan Citra

# %% [markdown]
# Nama : Aufa Akmal Labib

# %%
#Langkah 1
#Import Header yang dibutuhkan

import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import Image
from google.colab import drive
drive.mount('/content/drive')

import matplotlib.pylab as plt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Langkah 2
gambar1 = '/content/drive/MyDrive/KueTradisional/train/kue_serabi/1.jpg'
gambar2 = '/content/drive/MyDrive/KueTradisional/train/kue_dadar_gulung/19.jpg'
gambar3 = '/content/drive/MyDrive/KueTradisional/train/kue_lumpur/1.jpg'

urls = [gambar1,gambar2,gambar3]

# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = cv.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image

#Langkah3
#Melihat ukuran file image
  tinggi = image_2.shape[0]
  lebar = image_2.shape[1]
  print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# resolusi image: tinggi x lebar =  203  x  300
# <PIL.Image.Image image mode=RGB size=600x203 at 0x7FF30B8E4D60>
# resolusi image: tinggi x lebar =  225  x  225
# <PIL.Image.Image image mode=RGB size=450x225 at 0x7FF30B80E310>
# resolusi image: tinggi x lebar =  130  x  172
# <PIL.Image.Image image mode=RGB size=344x130 at 0x7FF30B80E5B0>

# %%
# LANGKAH 4
# Mengakses pixel dengan memberi garis diagonal menyilang
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal di tengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=344x130 at 0x7FF30B81D2E0>

# %% [markdown]
# 1.	Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
#
# Jawaban :
#
# Google Colab adalah lingkungan pengembangan berbasis web yang disediakan oleh Google secara gratis. Hal tersebut memungkinkan pengguna untuk menulis, menjalankan, dan menyimpan kode Python pada infrastruktur cloud yang kuat dan skalabel. Ada beberapa alasan mengapa program tersebut dieksekusi menggunakan Google Colab :
#
# *   Infrastruktur Kuat, Google Colab menggunakan infrastruktur cloud Google, yang memastikan bahwa kode program akan dieksekusi dengan performa yang baik dan cepat.
# *   Gratis, Google Colab tersedia secara gratif untuk siapa saja, sehingga tidak perlu membeli peralatan mahal untuk menjalankan kode Python.
#
# *   Integrasi dengan Google Drive, Google Colab memungkinkan program disimpan dalam Google Drive, membuatnya mudah untuk berbagi dan mengakses program dari mana saja.
# *   Ketersediaan GPU dan TPU, Google Colab menawarkan akses gratis ke GPU dan TPU untuk menjalankan program, membuatnya ideal untuk tugas-tugas yang membutuhkan banyak pemrosesan.
# *   Kemudahan Berkolaborasi, Google Colab memungkinkan beberapa orang untuk bekerja pada satu dokumen secara bersamaan, membuatnya mudah untuk bekerja dalam tim atau berkolaborasi dengan orang lain.

# %% [markdown]
# 2.	Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apa semua library tersebut harus digunakan dalam praktikum sesi ini?
#
# Jawaban :
#
# NumPy, digunakan untuk melakukan pemograman numerik. Numpy memiliki
#
# *   beberapa kegunaan yaitu : Pengolahan Array Multidimensional, Integrasi dengan Fungsi Matematika, Performa Tinggi, Integrasi dengan Library lain (Pandas, Matplotlib, dan SciPy), Fungsi Broadcasting.
# *   Pandas, digunakan untuk analisis data. Pandas memiliki beberapa kegunaan yaitu : struktur data (Series dan DataFrame), Input/Output data, manupulasi data (filtering, aggregasi, dan pembersihan data), analisis statistik (deskripsi statistik, grouping, dan pivot tables), dan visualisasi data.
# *   CV2, digunakan untuk pemrosesan gambar dan computer vision. CV2 memiliki beberapa kegunaan yaitu : pengolahan gambar (ukuran, rotasi, dan pemotongan), deteksi wajah dan objek, analisis teks dan huruf, pemantauan dan pengenalan pola, dan integrasi dengan library lain (NumPy, dan Pandas).
# *   Google.colab.patches, digunakan untuk memodifikasi atau memperluas fungsionalitas Google Colab. Library tersebut memiliki beberapa kegunaan yaitu : Modifikasi Tampilan (menambah atau menghapus tombol), Integrasi dengan sumber data eksternal (Google Drive), eksekusi perintah terminal, dan penambahan fitur baru.
# *   Skimage, digunakan untuk pemrosesan gambar dan computer vision. Skimage memiliki beberapa kegunaan utama yaitu : pengolahan gambar (ukuran, rotasi, dan pemotongan), deteksi wajah dan objek, analisis citra, segmentasi citra, dan integrasi dengan library lain (NumPy, dan Pandas)
# *   PIL (Python Image Library), digunakan untuk memproses gambar. PIL memiliki beberapa kegunaan yaitu : membuka dan menyimpan gambar, pengolahan gambar (rotasi, flip, dan pemotongan), analisis citra, dan konversi gambar.
# *   Matplotlib, digunakan untuk mempermudahkan pembuatan visualisasi data. Matplotlib memiliki beberapa kegunaan yaitu : plotting data (line plots, scatter plots, dan histograms), customisasi plot (warna, label, dan legenda), integrasi dengan library lain (NumPy, dan Pandas), dan export plot (PNG, SGV, dan PDF).

# %% [markdown]
# 3.	Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
#
# ![image.png](data:image/png;base64,...)
#
# Apa kegunaan kode program tersebut? Dan apa pengaruhnya jika tidak digunakan?
#
# Jawaban :
#
# Program tersebut adalah bagian dari library cv2 digunakan untuk mengubah ukuran gambar. Parameter – parameter yang digunakan dalam program tersebut adalah :
#
# *   “image” : variabel yang menyimpan gambar yang akan diubah ukurannya
# *   “(0,0)” : parameter ini menentukan ukuran gambar setelah diubah, dengan nilai (0,0) berati ukuran akan diubah secara dinamis berdasarkan nilai fx dan fy.
# *   “fx=0.5” : parameter ini menentukan skala perubahan ukuran gambar secara horizontal. Nilai 0.5 berarti gambar akan diperkecil sebesar 50 %.
# *   “fy=0.5” : parameter ini menentukan skala perubahan ukuran gambar secara vertikal. Nilai 0.5 berarti gambar akan diperkecil sebesar 50 %.
#
# Jika program tersebut tidak digunakan maka ukuran gambar akan sebesar aslinya, tidak diperkecil.

# %% [markdown]
# 4.	Perhatikan potongan kode program berikut :
#
# ![image.png](data:image/png;base64,...)
#
# Apa kegunaan kode [255,255,255]?jelaskan!
#
# Jawaban :
#
# Dalam program tersebut, [255,255,255] merepresentasikan warna putih dalam format RGB. Dalam sistem RGB, warna dalam citra digital dinyatakan sebagai nilai intensitas untuk masing-masing warna Red, Green, dan Blue. Nilai intensitas untuk masing-masing warna dinyatakan dengan bilangan bulat biner antara 0 dan 255. [255,255,255] menunjukkan bahwa intensitas maksimal dari Red, Green, dan Bule sehingga menghasilkan warna putih. Dalam program, warna putih diterapkan pada titik/garis sebagai penanda garis vertikal, horizontal, dan diagonal pada tergantung program yang dituliskan. Pada program tersebut digunakan untuk membuat garis diagonal tanpa memanfaatkan cv.line.

# %% [markdown]
# 5.	Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
# Jawaban :
#
# Pixel (Picture Element) merupakan unit terkecil dalam gambar digital. Jumlah pixel dalam suatu gambar menentukan resolusi gambar, yaitu jumlah detail yang dapat ditampilkan dalam gambar tersebut. Gambar dengan resolusi tinggi memiliki jumlah pixel yang lebih besar, sehingga dapat menampilkan detail yang lebih banyak dan lebih jelas. Sebaliknya, gambar dengan resolusi rendah memiliki jumlah pixel yang lebih sedikit, sehingga detail yang ditampilkan kurang jelas dan mungkin kabur.

# %%
# TUGAS
# GARIS VERTIKAL dan DIAGONAL
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis vertikal di tengah image
for x in range (tinggi):
  image_3[x, int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

# membuat garis diagonal
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

line1_1 = (0,0)
line1_2 = (lebar,tinggi)

line2_1 = (lebar,0)
line2_2 = (0,tinggi)

cv.line(image_3, line1_1, line1_2, (255,255,255))
cv.line(image_3, line2_1, line2_2, (255,255,255))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=344x130 at 0x7FF30B81DEB0>
# <PIL.Image.Image image mode=RGB size=344x130 at 0x7FF30B81DEB0>

# %%
# membuat garis diagonal tanpa cv.line
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (tinggi):
  image_3[y,int(y*(lebar/tinggi))] = [255,255,255]
  image_3[y,lebar-1-int(y*(lebar/tinggi))] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=344x130 at 0x7FF30B8E4AF0>

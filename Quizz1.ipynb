# %% [markdown]
# <a href="https://colab.research.google.com/github/Akmallabib/FCVK_Jobsheet1/blob/main/Quizz1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Quizz 1

# %% [markdown]
# Nama : Aufa Akmal Labib
#
# NIM  : 200536626430
#
# Prodi: S1 Teknik Elektro

# %%
# mengakses gdrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# header
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# mengambil gambar dari gdrive
img = cv.imread('/content/drive/MyDrive/soal3.jpg')
plt.imshow(img)

# %% [markdown]
# 1. Merubah Warna (Blue Red Green)

# %%
# Background Merah
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,(1,2)] = 0
plt.imshow(img3)

# %%
# Background Hijau
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,(0,2)] = 0
plt.imshow(img3)

# %%
# Background Kuning
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,(2,2)] = 0
plt.imshow(img3)

# %%
# Background Biru
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,(0,0)] = 0
plt.imshow(img3)

# %%
img_emot = cv.imread('/content/drive/MyDrive/soal3.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_emot)

# %%
# Background biru emot putih
plt.imshow(img_emot, cmap='Blues')

# %%
# Background hijau emot putih
plt.imshow(img_emot, cmap='Greens')

# %% [markdown]
# 2. Merubah Ukuran

# %%
# resize gambar (512px , 1024px)
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %% [markdown]
# 3. Membuat garis vertikal, horizontal

# %%
# inisialisasi gambar
gambar1 = img

# ambil gambar
urls = [gambar1]
for url in urls:
  image = img
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image

# menampilkan tinggi dan lebar gambar
  tinggi = image_2.shape[0]
  lebar = image_2.shape[1]
  print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# resolusi image: tinggi x lebar =  126  x  406
# <PIL.Image.Image image mode=RGB size=812x126 at 0x7FE013942220>

# %%
# mengambil gambar
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

# menampilkan gambar
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=812x126 at 0x7FE013936CA0>

# %%
# mengambil gambar
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis vertikal
for x in range (tinggi):
  image_3[x, int((lebar)/2)] = [255,255,255]

# menampilkan gambar
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=812x126 at 0x7FE0139428B0>

# %% [markdown]
# 4. Flip vertikal / horizontal

# %%
# Vertikal
img_flip = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)
plt.imshow(img_flip)

# %%
# Horizontal
img_flip = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 1)
plt.imshow(img_flip)

# %% [markdown]
# 5. Menambah shape

# %%
# inisialisasi gambar
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)

# proses penambahan shape

# shape rectagle
cv.rectangle(img3,pt1=(150,150),pt2=(250,80),color=(255,0,0),thickness=5) # red
cv.rectangle(img3,pt1=(390,150),pt2=(480,80),color=(0,255,0),thickness=5) # green
cv.rectangle(img3,pt1=(630,150),pt2=(720,80),color=(0,0,255),thickness=5) # blue

# shape line
cv.line(img3,pt1=(250,100),pt2=(300,80),color=(0,255,255),thickness=10) # tosca
cv.line(img3,pt1=(100,80),pt2=(150,100),color=(0,255,255),thickness=10) # tosca
cv.line(img3,pt1=(450,180),pt2=(450,150),color=(0,255,255),thickness=10) # tosca

# shape circle
cv.circle(img3,center=(570,50),radius=30,color=(0,0,0),thickness=8) # hitam
cv.circle(img3,center=(790,50),radius=30,color=(0,0,0),thickness=8) # hitam

# menampilkan gambar
plt.imshow(img3)
